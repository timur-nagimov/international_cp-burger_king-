# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import joblib

# %%
dan_train = joblib.load('/kaggle/input/international-cp/data/new_train_features.pkl')
dan_test = joblib.load('/kaggle/input/international-cp/data/new_test_features.pkl')

polina_train = joblib.load('/kaggle/input/bk-agg-features-data/train_agg_320_feats_no_corr_no_target.pkl')
polina_test = joblib.load('/kaggle/input/bk-agg-features-data/test_agg_320_feats_no_corr.pkl')

lev_train = joblib.load('/kaggle/input/bk-new-aggr-features/new_train_aggr_features.pkl')
lev_test = joblib.load('/kaggle/input/bk-new-aggr-features/new_test_aggr_features.pkl')

polina_train.reset_index(inplace = True)
polina_test.reset_index(inplace = True)

dan_train = dan_train[['customer_id', 'date_diff_post', 'buy_post', 
        'tfidf_format_name_без', 'tfidf_format_name_внешн',
       'tfidf_format_name_внешней', 'tfidf_format_name_заполнено',
       'tfidf_format_name_зоной', 'tfidf_format_name_зоны',
       'tfidf_format_name_не', 'tfidf_format_name_отдельно',
       'tfidf_format_name_стоящий', 'tfidf_format_name_туалета',
       'tfidf_format_name_туалетом', 'tfidf_format_name_фудкорт',
       'tfidf_dish_name_а4', 'tfidf_dish_name_бокс', 'tfidf_dish_name_бургеры',
       'tfidf_dish_name_говядина', 'tfidf_dish_name_горячие',
       'tfidf_dish_name_десерты', 'tfidf_dish_name_дополнительно',
       'tfidf_dish_name_закуски', 'tfidf_dish_name_картофель',
       'tfidf_dish_name_кинг', 'tfidf_dish_name_коктейли',
       'tfidf_dish_name_комбо', 'tfidf_dish_name_креветки',
       'tfidf_dish_name_купоны', 'tfidf_dish_name_курица',
       'tfidf_dish_name_молочные', 'tfidf_dish_name_напитки',
       'tfidf_dish_name_новинки', 'tfidf_dish_name_обед',
       'tfidf_dish_name_острые', 'tfidf_dish_name_острый',
       'tfidf_dish_name_пиво', 'tfidf_dish_name_роллы', 'tfidf_dish_name_рыба',
       'tfidf_dish_name_салаты', 'tfidf_dish_name_сет',
       'tfidf_dish_name_соусы', 'tfidf_dish_name_топ',
       'tfidf_dish_name_холодные']]
dan_test = dan_test[['customer_id',
        'tfidf_format_name_без', 'tfidf_format_name_внешн',
       'tfidf_format_name_внешней', 'tfidf_format_name_заполнено',
       'tfidf_format_name_зоной', 'tfidf_format_name_зоны',
       'tfidf_format_name_не', 'tfidf_format_name_отдельно',
       'tfidf_format_name_стоящий', 'tfidf_format_name_туалета',
       'tfidf_format_name_туалетом', 'tfidf_format_name_фудкорт',
       'tfidf_dish_name_а4', 'tfidf_dish_name_бокс', 'tfidf_dish_name_бургеры',
       'tfidf_dish_name_говядина', 'tfidf_dish_name_горячие',
       'tfidf_dish_name_десерты', 'tfidf_dish_name_дополнительно',
       'tfidf_dish_name_закуски', 'tfidf_dish_name_картофель',
       'tfidf_dish_name_кинг', 'tfidf_dish_name_коктейли',
       'tfidf_dish_name_комбо', 'tfidf_dish_name_креветки',
       'tfidf_dish_name_купоны', 'tfidf_dish_name_курица',
       'tfidf_dish_name_молочные', 'tfidf_dish_name_напитки',
       'tfidf_dish_name_новинки', 'tfidf_dish_name_обед',
       'tfidf_dish_name_острые', 'tfidf_dish_name_острый',
       'tfidf_dish_name_пиво', 'tfidf_dish_name_роллы', 'tfidf_dish_name_рыба',
       'tfidf_dish_name_салаты', 'tfidf_dish_name_сет',
       'tfidf_dish_name_соусы', 'tfidf_dish_name_топ',
       'tfidf_dish_name_холодные']]

# %%
merged_train = dan_train.merge(polina_train, on = 'customer_id', how = 'inner')
merged_train = merged_train.merge(lev_train, on = 'customer_id', how = 'inner')

merged_test = dan_test.merge(polina_test, on = 'customer_id', how = 'inner')
merged_test = merged_test.merge(lev_test, on = 'customer_id', how = 'inner')

# %% [markdown]
# ## Classification

# %%
y = merged_train['buy_post']
X = merged_train.drop(['buy_post'], axis=1)

# %%
from imblearn.under_sampling import RandomUnderSampler

under_sampler = RandomUnderSampler(sampling_strategy=1.0, random_state=42)

X_resampled, y_resampled = under_sampler.fit_resample(X, y)

# %%
from sklearn.model_selection import train_test_split

y_buy = y_resampled
y_days = X_resampled['date_diff_post']
X = X_resampled.drop(['customer_id', 'date_diff_post'], axis=1)

X_train, X_valid, y_train_buy, y_valid_buy, y_train_days, y_valid_days = train_test_split(X, y_buy, y_days, random_state=42, shuffle=True, stratify = y_buy,test_size=0.3)

# %%
from catboost import CatBoostClassifier, metrics
CatBoostModel = CatBoostClassifier(
    iterations= 500,
    learning_rate = 0.065,
    use_best_model = True,
    eval_metric ='F1', 
    loss_function='Logloss',
    random_seed = 42,
    depth = 5,
    verbose = 100
)

# %%
CatBoostModel.fit(
    X_train, y_train_buy,
    eval_set=(X_valid, y_valid_buy)
)
# Out:
# 0:	learn: 0.6227125	test: 0.6185044	best: 0.6185044 (0)	total: 289ms	remaining: 2m 24s
# 100:	learn: 0.6547015	test: 0.6505420	best: 0.6522378 (14)	total: 21.8s	remaining: 1m 26s
# 200:	learn: 0.6577828	test: 0.6512560	best: 0.6522378 (14)	total: 39.8s	remaining: 59.2s
# 300:	learn: 0.6609423	test: 0.6519424	best: 0.6522778 (233)	total: 56.9s	remaining: 37.6s
# 400:	learn: 0.6642799	test: 0.6519710	best: 0.6522778 (233)	total: 1m 13s	remaining: 18.1s
# 499:	learn: 0.6666631	test: 0.6520830	best: 0.6522778 (233)	total: 1m 30s	remaining: 0us
#
# bestTest = 0.6522778193
# bestIteration = 233
#
# Shrink model to first 234 iterations.

# %%
feature_importance = CatBoostModel.feature_importances_
sorted_idx = np.argsort(feature_importance)[330:]

plt.figure(figsize=(15, 10))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(CatBoostModel.feature_names_)[sorted_idx])
plt.title("Feature Importance")
plt.show()

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, roc_auc_score

predictions_auc = CatBoostModel.predict_proba(X_valid)[:, 1]
print(f'roc_auc: {roc_auc_score(y_valid_buy, predictions_auc)}')

predictions = CatBoostModel.predict(X_valid)
print(f'f1: {f1_score(y_valid_buy, predictions)}')
print(f'precision: {precision_score(y_valid_buy, predictions)}')
print(f'recall: {recall_score(y_valid_buy, predictions)}')
# Out:
# roc_auc: 0.7364865766633093
# f1: 0.6522778192681105
# precision: 0.688276550474139
# recall: 0.6198575855787656

# %%
predictions_val = CatBoostModel.predict(X_valid)
predictions_test = CatBoostModel.predict(merged_test[CatBoostModel.feature_names_])

# %%
from collections import Counter
print(Counter(predictions_val))
print(Counter(predictions_test))
# Out:
# Counter({0: 46474, 1: 38069})
# Counter({0: 61733, 1: 50601})

# %%
merged_test['preds'] = predictions_test

# %%
submit = pd.read_csv('/kaggle/input/international-cp/submission.csv', sep = ';')

# %%
submit = submit.merge(merged_test[['customer_id', 'preds']], on = 'customer_id', how = 'inner')

# %%
submit['buy_post'] = submit['preds']
submit.drop(columns = ['preds'], inplace = True)

# %%
submit.to_csv('merged_all_dpl_0045.csv', sep = ';', index = False)

# %%
with open('best_model_dpl_067_0045.pkl', "wb") as f:
    pickle.dump(CatBoostModel, f)

# %% [markdown]
# ## Visualisation

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(y_true, y_scores, label, color, linestyle):
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, color=color, lw=2, label=f'{label} (AUC = {roc_auc:.4f})', linestyle=linestyle)

y_true_train = y_train_buy
y_scores_train = CatBoostModel.predict_proba(X_train)[:, 1]

y_true_valid = y_valid_buy
y_scores_valid = CatBoostModel.predict_proba(X_valid)[:, 1]

roc_auc_color = '#6839CF'

plt.figure(figsize=(8, 8))

plot_roc_curve(y_true_train, y_scores_train, 'Train', color=roc_auc_color, linestyle='--')

plot_roc_curve(y_true_valid, y_scores_valid, 'Valid', color=roc_auc_color, linestyle='-')

plt.plot([0, 1], [0, 1], color='grey', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-AUC Curve')
plt.legend(loc="lower right")

plt.show()

# %%
from sklearn.metrics import precision_recall_curve, auc

def plot_pr_curve(y_true, y_scores, label, color, linestyle):
    precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
    pr_auc = auc(recall, precision)

    plt.plot(recall, precision, color=color, lw=2, label=f'{label} (AUC = {pr_auc:.4f})', linestyle=linestyle)

y_true_train = y_train_buy
y_scores_train = CatBoostModel.predict_proba(X_train)[:, 1]

y_true_valid = y_valid_buy
y_scores_valid = CatBoostModel.predict_proba(X_valid)[:, 1]

pr_auc_color = '#6839CF'

plt.figure(figsize=(8, 8))

plot_pr_curve(y_true_train, y_scores_train, 'Train', color=pr_auc_color, linestyle='--')

plot_pr_curve(y_true_valid, y_scores_valid, 'Valid', color=pr_auc_color, linestyle='-')

plt.plot([0, 1], [1, 0], color='grey', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# ## Regression

# %%
preds = CatBoostModel.predict(merged_train[CatBoostModel.feature_names_])
merged_train['preds'] = preds

preds_prob = CatBoostModel.predict_proba(merged_train[CatBoostModel.feature_names_])[:, 1]
merged_train['preds_prob'] = preds_prob

# %%
merged_train_reg = merged_train[merged_train['preds'] == 1]

# %%
merged_train_reg['date_diff_post'].fillna(0, inplace = True)

# %%
from sklearn.model_selection import train_test_split

y_days = merged_train_reg['date_diff_post']
X = merged_train_reg.drop(['customer_id', 'date_diff_post', 'preds', 'buy_post'], axis=1)

X_train, X_valid, y_train_days, y_valid_days = train_test_split(X, y_days, random_state=42, shuffle=True, test_size=0.3)

# %%
from catboost import CatBoostRegressor, metrics
cb_regr = CatBoostRegressor(
    iterations= 500,
    use_best_model = True,
    eval_metric ='RMSE', 
    loss_function='RMSE',
    random_seed = 42,
    verbose = 100
)

# %%
cb_regr.fit(
    X_train, y_train_days,
    eval_set=(X_valid, y_valid_days)
)
# Out:
# Learning rate set to 0.17625
# 0:	learn: 14.8655638	test: 14.8416648	best: 14.8416648 (0)	total: 227ms	remaining: 1m 53s
# 100:	learn: 14.3123671	test: 14.4077481	best: 14.4077481 (100)	total: 19.9s	remaining: 1m 18s
# 200:	learn: 14.1630877	test: 14.4046534	best: 14.3998188 (121)	total: 38.2s	remaining: 56.8s
# 300:	learn: 14.0285003	test: 14.4066840	best: 14.3998188 (121)	total: 56s	remaining: 37s
# 400:	learn: 13.8983277	test: 14.4138297	best: 14.3998188 (121)	total: 1m 14s	remaining: 18.4s
# 499:	learn: 13.7756963	test: 14.4205209	best: 14.3998188 (121)	total: 1m 32s	remaining: 0us
#
# bestTest = 14.39981879
# bestIteration = 121
#
# Shrink model to first 122 iterations.

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

preds = cb_regr.predict(X_valid)
print(f'r2: {r2_score(y_valid_days, preds)}')
print(f'mse: {mean_squared_error(y_valid_days, preds)}')
print(f'rmse: {mean_squared_error(y_valid_days, preds, squared = False)}')
print(f'mae: {mean_absolute_error(y_valid_days, preds)}')
# Out:
# r2: 0.07474363786273419
# mse: 207.35478119343284
# rmse: 14.399818790298468
# mae: 11.309989162029451

# %%
feature_importance = cb_regr.feature_importances_
sorted_idx = np.argsort(feature_importance)[330:]

plt.figure(figsize=(15, 10))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(cb_regr.feature_names_)[sorted_idx])
plt.title("Feature Importance")
plt.show()

# %%
import optuna

def objective(trial):
    params = {
        "objective": "RMSE",  # Changed to RMSE for regression
        "learning_rate": trial.suggest_loguniform("learning_rate", 1e-5, 1e0),
        "l2_leaf_reg": trial.suggest_loguniform("l2_leaf_reg", 1e-2, 3e0),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1, log=True),
        "depth": trial.suggest_int("depth", 2, 5),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 2, 50),
        "one_hot_max_size": trial.suggest_int("one_hot_max_size", 2, 50),
        "iterations": trial.suggest_int("iterations", 500, 3500),
        "eval_metric": "RMSE"
    }

    if params["bootstrap_type"] == "Bayesian":
        params["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif params["bootstrap_type"] == "Bernoulli":
        params["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    model = CatBoostRegressor(
        loss_function='RMSE',
        random_seed=42,
        task_type='CPU',
        use_best_model=True,
        verbose=False,
        **params
    )
    
    model.fit(
        X_train, y_train_days,
        eval_set=(X_valid, y_valid_days)
    )

    y_pred = model.predict(X_valid)

    rmse = mean_squared_error(y_valid_days, y_pred, squared = False)

    return rmse

study = optuna.create_study(pruner=optuna.pruners.MedianPruner(n_warmup_steps = 5), direction = "minimize")
study.optimize(objective, n_trials = 100, timeout = 1800)

print("Best params:", study.best_params)
# Out:
# [I 2023-11-24 22:01:02,825] A new study created in memory with name: no-name-bc6f04e1-000e-4455-a2f1-e522477efc81
# [I 2023-11-24 22:01:53,457] Trial 0 finished with value: 14.96396628275304 and parameters: {'learning_rate': 1.618580224302681e-05, 'l2_leaf_reg': 0.05744882947282084, 'colsample_bylevel': 0.04338047868347101, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 16, 'one_hot_max_size': 26, 'iterations': 968, 'subsample': 0.1595840577565395}. Best is trial 0 with value: 14.96396628275304.
# [I 2023-11-24 22:02:25,538] Trial 1 finished with value: 14.600545341418321 and parameters: {'learning_rate': 0.0028630895904938627, 'l2_leaf_reg': 1.5053943400510648, 'colsample_bylevel': 0.011802365760397057, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 31, 'one_hot_max_size': 10, 'iterations': 1849, 'bagging_temperature': 1.3061694730174256}. Best is trial 1 with value: 14.600545341418321.
# [I 2023-11-24 22:02:51,754] Trial 2 finished with value: 14.96656513668187 and parameters: {'learning_rate': 2.7405477911350755e-05, 'l2_leaf_reg': 0.04809609922812079, 'colsample_bylevel': 0.030189725235646742, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 37, 'one_hot_max_size': 45, 'iterations': 1014, 'bagging_temperature': 7.211593601007288}. Best is trial 1 with value: 14.600545341418321.
# [I 2023-11-24 22:03:44,759] Trial 3 finished with value: 14.930845180193716 and parameters: {'learning_rate': 5.587951965275808e-05, 'l2_leaf_reg': 0.503069024803909, 'colsample_bylevel': 0.042911720052628985, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 25, 'one_hot_max_size': 44, 'iterations': 3022}. Best is trial 1 with value: 14.600545341418321.
# [I 2023-11-24 22:04:09,881] Trial 4 finished with value: 14.538624664086537 and parameters: {'learning_rate': 0.934836076258525, 'l2_leaf_reg': 0.14729860491416502, 'colsample_bylevel': 0.010648974736673153, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 10, 'one_hot_max_size': 46, 'iterations': 2093}. Best is trial 4 with value: 14.538624664086537.
# [I 2023-11-24 22:05:28,538] Trial 5 finished with value: 14.593336103951314 and parameters: {'learning_rate': 0.0010653054770170898, 'l2_leaf_reg': 0.9039998781468632, 'colsample_bylevel': 0.020235125243955047, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 12, 'one_hot_max_size': 29, 'iterations': 3108}. Best is trial 4 with value: 14.538624664086537.
# [I 2023-11-24 22:05:55,035] Trial 6 finished with value: 14.473692265324164 and parameters: {'learning_rate': 0.4078592083845192, 'l2_leaf_reg': 0.7410186200646669, 'colsample_bylevel': 0.010376386980888322, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 34, 'one_hot_max_size': 24, 'iterations': 1999, 'subsample': 0.3652871656123479}. Best is trial 6 with value: 14.473692265324164.
# [I 2023-11-24 22:07:37,904] Trial 7 finished with value: 14.447660708892212 and parameters: {'learning_rate': 0.015738709860266292, 'l2_leaf_reg': 0.7114400244107942, 'colsample_bylevel': 0.09450776096099163, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 20, 'one_hot_max_size': 27, 'iterations': 3296, 'subsample': 0.26802666376548984}. Best is trial 7 with value: 14.447660708892212.
# [I 2023-11-24 22:08:42,745] Trial 8 finished with value: 14.456927357728558 and parameters: {'learning_rate': 0.04038747762272976, 'l2_leaf_reg': 0.049446746351065274, 'colsample_bylevel': 0.013580933992726711, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'min_data_in_leaf': 47, 'one_hot_max_size': 3, 'iterations': 3102, 'bagging_temperature': 3.3176251884994357}. Best is trial 7 with value: 14.447660708892212.
# [I 2023-11-24 22:09:30,061] Trial 9 finished with value: 14.46175507635002 and parameters: {'learning_rate': 0.006370521416772057, 'l2_leaf_reg': 2.1244010531335777, 'colsample_bylevel': 0.04202862627603978, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'min_data_in_leaf': 22, 'one_hot_max_size': 3, 'iterations': 2030}. Best is trial 7 with value: 14.447660708892212.
# [I 2023-11-24 22:14:18,992] Trial 10 finished with value: 14.397840130276323 and parameters: {'learning_rate': 0.04858427437508204, 'l2_leaf_reg': 0.015360446903609796, 'colsample_bylevel': 0.09533504806481252, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 50, 'one_hot_max_size': 34, 'iterations': 3485, 'subsample': 0.8573450381043685}. Best is trial 10 with value: 14.397840130276323.
# [I 2023-11-24 22:19:15,770] Trial 11 finished with value: 14.395713798390187 and parameters: {'learning_rate': 0.043551334982513575, 'l2_leaf_reg': 0.012250049556034997, 'colsample_bylevel': 0.09646699668338604, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 2, 'one_hot_max_size': 33, 'iterations': 3491, 'subsample': 0.8798848833231431}. Best is trial 11 with value: 14.395713798390187.
# [I 2023-11-24 22:22:54,999] Trial 12 finished with value: 14.398123932638399 and parameters: {'learning_rate': 0.10083063080435888, 'l2_leaf_reg': 0.011720838959917932, 'colsample_bylevel': 0.08601215197147612, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 4, 'one_hot_max_size': 34, 'iterations': 2594, 'subsample': 0.9760764323552014}. Best is trial 11 with value: 14.395713798390187.
# [I 2023-11-24 22:26:08,043] Trial 13 finished with value: 14.400583609471784 and parameters: {'learning_rate': 0.07724934850381449, 'l2_leaf_reg': 0.010223339383107098, 'colsample_bylevel': 0.07305888743675343, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 50, 'one_hot_max_size': 37, 'iterations': 2635, 'subsample': 0.944143570723607}. Best is trial 11 with value: 14.395713798390187.
# [I 2023-11-24 22:29:16,179] Trial 14 finished with value: 14.424088492579997 and parameters: {'learning_rate': 0.17652719718736784, 'l2_leaf_reg': 0.02030998195070894, 'colsample_bylevel': 0.06864101561373163, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 40, 'one_hot_max_size': 16, 'iterations': 3493, 'subsample': 0.6221064040856141}. Best is trial 11 with value: 14.395713798390187.
# [I 2023-11-24 22:32:05,653] Trial 15 finished with value: 14.415924714912787 and parameters: {'learning_rate': 0.020283206194638435, 'l2_leaf_reg': 0.023626421453597737, 'colsample_bylevel': 0.061703841229323646, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 2, 'one_hot_max_size': 37, 'iterations': 2564, 'subsample': 0.5604469296245117}. Best is trial 11 with value: 14.395713798390187.
# Best params: {'learning_rate': 0.043551334982513575, 'l2_leaf_reg': 0.012250049556034997, 'colsample_bylevel': 0.09646699668338604, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'min_data_in_leaf': 2, 'one_hot_max_size': 33, 'iterations': 3491, 'subsample': 0.8798848833231431}

# %%
with open('model_dpl_regr_0130.pkl', "wb") as f:
    pickle.dump(cb_regr, f)

# %%
best_params = {
    'learning_rate': 0.043551334982513575, 
    'l2_leaf_reg': 0.012250049556034997, 
    'colsample_bylevel': 0.09646699668338604, 
    'depth': 3, 
    'boosting_type': 'Ordered', 
    'bootstrap_type': 'Bernoulli', 
    'min_data_in_leaf': 2, 
    'one_hot_max_size': 33, 
    'iterations': 3491, 
    'subsample': 0.8798848833231431,
    'verbose': 100,
    'use_best_model': True
}

# %%
cb_regr_opt = CatBoostRegressor(**best_params)

# %%
cb_regr_opt.fit(
    X_train, y_train_days,
    eval_set=(X_valid, y_valid_days)
)
# Out:
# 0:	learn: 14.9836203	test: 14.9576285	best: 14.9576285 (0)	total: 82.7ms	remaining: 4m 48s
# 100:	learn: 14.5200418	test: 14.5036469	best: 14.5036469 (100)	total: 8.86s	remaining: 4m 57s
# 200:	learn: 14.4703662	test: 14.4628083	best: 14.4628083 (200)	total: 17.2s	remaining: 4m 41s
# 300:	learn: 14.4458186	test: 14.4458552	best: 14.4458552 (300)	total: 25.9s	remaining: 4m 34s
# 400:	learn: 14.4287857	test: 14.4358505	best: 14.4358505 (400)	total: 34.1s	remaining: 4m 23s
# 500:	learn: 14.4170492	test: 14.4309315	best: 14.4309018 (498)	total: 42.5s	remaining: 4m 13s
# 600:	learn: 14.4062244	test: 14.4263355	best: 14.4263355 (600)	total: 50.8s	remaining: 4m 4s
# 700:	learn: 14.3963340	test: 14.4223033	best: 14.4223033 (700)	total: 59.7s	remaining: 3m 57s
# 800:	learn: 14.3872043	test: 14.4193434	best: 14.4193249 (797)	total: 1m 7s	remaining: 3m 48s
# 900:	learn: 14.3782265	test: 14.4159239	best: 14.4159239 (900)	total: 1m 16s	remaining: 3m 39s
# 1000:	learn: 14.3692889	test: 14.4132719	best: 14.4132719 (1000)	total: 1m 24s	remaining: 3m 31s
# 1100:	learn: 14.3616770	test: 14.4120644	best: 14.4120644 (1100)	total: 1m 33s	remaining: 3m 22s
# 1200:	learn: 14.3531916	test: 14.4089618	best: 14.4089618 (1200)	total: 1m 41s	remaining: 3m 13s
# 1300:	learn: 14.3454266	test: 14.4067699	best: 14.4066464 (1294)	total: 1m 49s	remaining: 3m 4s
# 1400:	learn: 14.3383907	test: 14.4048154	best: 14.4048154 (1400)	total: 1m 58s	remaining: 2m 56s
# 1500:	learn: 14.3308745	test: 14.4032627	best: 14.4032159 (1498)	total: 2m 6s	remaining: 2m 48s
# 1600:	learn: 14.3240388	test: 14.4017063	best: 14.4016725 (1598)	total: 2m 15s	remaining: 2m 39s
# 1700:	learn: 14.3171526	test: 14.4010395	best: 14.4009934 (1685)	total: 2m 23s	remaining: 2m 31s
# 1800:	learn: 14.3105079	test: 14.4000059	best: 14.3999637 (1793)	total: 2m 32s	remaining: 2m 22s
# 1900:	learn: 14.3046248	test: 14.3992074	best: 14.3992074 (1900)	total: 2m 40s	remaining: 2m 14s
# 2000:	learn: 14.2982096	test: 14.3990762	best: 14.3990005 (1923)	total: 2m 48s	remaining: 2m 5s
# 2100:	learn: 14.2921342	test: 14.3981339	best: 14.3980593 (2084)	total: 2m 57s	remaining: 1m 57s
# 2200:	learn: 14.2861310	test: 14.3976289	best: 14.3975181 (2191)	total: 3m 5s	remaining: 1m 48s
# 2300:	learn: 14.2802975	test: 14.3971820	best: 14.3971569 (2299)	total: 3m 14s	remaining: 1m 40s
# 2400:	learn: 14.2746105	test: 14.3967284	best: 14.3966490 (2350)	total: 3m 22s	remaining: 1m 31s
# 2500:	learn: 14.2692209	test: 14.3964289	best: 14.3963437 (2495)	total: 3m 30s	remaining: 1m 23s
# 2600:	learn: 14.2637428	test: 14.3962626	best: 14.3961469 (2516)	total: 3m 39s	remaining: 1m 15s
# 2700:	learn: 14.2583284	test: 14.3957861	best: 14.3957110 (2669)	total: 3m 47s	remaining: 1m 6s
# 2800:	learn: 14.2531268	test: 14.3953705	best: 14.3952842 (2791)	total: 3m 56s	remaining: 58.1s
# 2900:	learn: 14.2474206	test: 14.3942990	best: 14.3942847 (2896)	total: 4m 4s	remaining: 49.8s
# 3000:	learn: 14.2417955	test: 14.3941997	best: 14.3941077 (2963)	total: 4m 13s	remaining: 41.3s
# 3100:	learn: 14.2362719	test: 14.3937329	best: 14.3937329 (3100)	total: 4m 21s	remaining: 32.9s
# 3200:	learn: 14.2312279	test: 14.3932802	best: 14.3932618 (3196)	total: 4m 29s	remaining: 24.4s
# 3300:	learn: 14.2255945	test: 14.3936989	best: 14.3932107 (3210)	total: 4m 38s	remaining: 16s
# 3400:	learn: 14.2204364	test: 14.3934076	best: 14.3932107 (3210)	total: 4m 47s	remaining: 7.6s
# 3490:	learn: 14.2159434	test: 14.3936520	best: 14.3931554 (3419)	total: 4m 54s	remaining: 0us
#
# bestTest = 14.39315537
# bestIteration = 3419
#
# Shrink model to first 3420 iterations.

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

preds = cb_regr_opt.predict(X_valid)
print(f'r2: {r2_score(y_valid_days, preds)}')
print(f'mse: {mean_squared_error(y_valid_days, preds)}')
print(f'rmse: {mean_squared_error(y_valid_days, preds, squared = False)}')
print(f'mae: {mean_absolute_error(y_valid_days, preds)}')
# Out:
# r2: 0.07559975241719241
# mse: 207.16292145230537
# rmse: 14.39315536817085
# mae: 11.29529181886409

# %%
with open('model_opt_dpl_regr.pkl', "wb") as f:
    pickle.dump(cb_regr_opt, f)

# %%
# без preds_prob

# %%
from sklearn.model_selection import train_test_split

y_days = merged_train_reg['date_diff_post']
X = merged_train_reg.drop(['customer_id', 'date_diff_post', 'preds', 'buy_post', 'preds_prob'], axis=1)

X_train, X_valid, y_train_days, y_valid_days = train_test_split(X, y_days, random_state=42, shuffle=True, test_size=0.3)

# %%
from catboost import CatBoostRegressor, metrics
cb_regr_no = CatBoostRegressor(
    iterations= 500,
    use_best_model = True,
    eval_metric ='RMSE', 
    loss_function='RMSE',
    random_seed = 42,
    verbose = 100
)

# %%
cb_regr_no.fit(
    X_train, y_train_days,
    eval_set=(X_valid, y_valid_days)
)
# Out:
# Learning rate set to 0.17625
# 0:	learn: 14.8620736	test: 14.8367961	best: 14.8367961 (0)	total: 251ms	remaining: 2m 5s
# 100:	learn: 14.3116148	test: 14.4110908	best: 14.4110908 (100)	total: 20.1s	remaining: 1m 19s
# 200:	learn: 14.1647485	test: 14.4054031	best: 14.4036989 (139)	total: 37.8s	remaining: 56.2s
# 300:	learn: 14.0385857	test: 14.4137514	best: 14.4036989 (139)	total: 55.7s	remaining: 36.8s
# 400:	learn: 13.9184692	test: 14.4268174	best: 14.4036989 (139)	total: 1m 12s	remaining: 18s
# 499:	learn: 13.7972941	test: 14.4330029	best: 14.4036989 (139)	total: 1m 31s	remaining: 0us
#
# bestTest = 14.40369891
# bestIteration = 139
#
# Shrink model to first 140 iterations.

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

preds = cb_regr_no.predict(X_valid)
print(f'r2: {r2_score(y_valid_days, preds)}')
print(f'mse: {mean_squared_error(y_valid_days, preds)}')
print(f'rmse: {mean_squared_error(y_valid_days, preds, squared = False)}')
print(f'mae: {mean_absolute_error(y_valid_days, preds)}')
# Out:
# r2: 0.07424493868340276
# mse: 207.46654228305428
# rmse: 14.403698909761141
# mae: 11.316105486281993

# %%
feature_importance = cb_regr_no.feature_importances_
sorted_idx = np.argsort(feature_importance)[330:]

plt.figure(figsize=(15, 10))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(cb_regr_no.feature_names_)[sorted_idx])
plt.title("Feature Importance")
plt.show()

# %%
with open('best_model_dpl_regr.pkl', "wb") as f:
    pickle.dump(cb_regr_no, f)
